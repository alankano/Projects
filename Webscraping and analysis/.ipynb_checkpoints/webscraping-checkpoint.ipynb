# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from bs4 import BeautifulSoup
import requests

# %%
#2015 - http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2015/janeiro/passageiros/Passag-20150101.xls
#2016 - http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2016/janeiro/passageiros/Passag-20160121.xls
#2017 - http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2017/janeiro/passageiros/Passag-20170105.xls
#2018 - http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/Passag-20180101.xls
#2019 - https://www.prefeitura.sp.gov.br/cidade/secretarias/upload/01012019.xls

# %%
df_definitivo = pd.DataFrame()

# %%
url_2014 = 'https://www.prefeitura.sp.gov.br/cidade/secretarias/transportes/institucional/sptrans/acesso_a_informacao/index.php?p=152417'
html_2014 = requests.get(url_2014)
content_2014 = html_2014.content
soup_2014 = BeautifulSoup(content_2014, 'lxml')

# %%
ahref = soup_2014.find_all('a')

# %%
#for link in soup_2014.find_all('a'):
    #print(link.get('href'))
    http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/2014/janeiro/passageiros/Passag-20140102.xls

# %%
day_list   = list(range(1,32))
days_list = []
for j in day_list:
    if j < 10:
        j = '0'+str(j)
    else :
        j = str(j)
    days_list.append(j)

# %%
year_2015_2017  = list(range(2014, 2017))
year_2018_2019  = [2018, 2019] 
month_list = {'janeiro' : '01', 
               'fevereiro': '02',
               'marco': '03',
               'abril': '04',
               'maio': '05',
               'junho': '06',
               'julho': '07',
               'agosto': '08',
               'setembro': '09',
               'outubro': '10',
               'novembro': '11',
               'dezembro': '12'
              }

# %%
missing_values_list = []
for year in year_2015_2017:
    for key in month_list.keys():
        mes = month_list[key]
        for j in days_list:
            try :
                url = 'http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/'+str(year)+'/'+str(key)+'/passageiros/Passag-'+str(year)+str(month)+str(j)+'.xls'
                df_temporario = pd.read_excel(url)
                print(url)
                break
                try:
                    df_definitivo = pd.concat(df_definitvo, df_temporario)
                except:
                    pass
            except:
                missing_values_list.append(str(year)+str(month)+str(j))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ddb4cfea8c0e> in <module>
#       7             try :
# ----> 8                 url = 'http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/'+str(year)+'/'+str(key)+'/passageiros/Passag-'+str(year)+str(month)+str(j)+'.xls'
#       9                 df_temporario = pd.read_excel(url)
#
# NameError: name 'month' is not defined
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-ddb4cfea8c0e> in <module>
#      15                     pass
#      16             except:
# ---> 17                 missing_values_list.append(str(year)+str(month)+str(j))
#      18
#
# NameError: name 'month' is not defined

# %%
lala = pd.read_excel('https://www.prefeitura.sp.gov.br/cidade/secretarias/upload/170718.xls')

# %%
monthlala = {'01' : 'janeiro'}
mes = monthlala['01']
days = list(range(10))
month_mes = list(monthlala)[0]
month_mes = str(month_mes)
for j in days_list:
    if j == 1:
        df_definitivo = pd.read_excel('http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2017/'+mes+'/passageiros/Passag-2017'+str(month_mes)+str(j)+'.xls')
    else :
        df_temporario = pd.read_excel('http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2017/'+mes+'/passageiros/Passag-2017'+str(month_mes)+str(j)+'.xls')
        df_definitivo = pd.concat([df_definitivo, df_temporario])

# %%
len(df_definitivo)
# Out:
# 39911

# %%
for j in days_list:
    url = 'http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2017/'+mes+'/passageiros/Passag-2017'+str(month_mes)+str(j)+'.xls'
    df_temporario = pd.read_excel(url)
    try :
        df_definitivo = pd.concat(df_definitivo, df_temporario)
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-47-e52fffe3d49f> in <module>
#       1 for j in days_list:
#       2     url = 'http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2017/'+mes+'/passageiros/Passag-2017'+str(month_mes)+str(j)+'.xls'
# ----> 3     df_temporario = pd.read_excel(url)
#       4     try :
#       5         df_definitivo = pd.concat(df_definitivo, df_temporario)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ...

# %%
missing_values_list_2018 = []
for key in month_list.keys():
    mes = month_list[key]
    for j in day_list:
        try :
            url = 'http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/transportes/SPTrans/acesso_a_informacao/2017/'+month+'/passageiros/Passag-2017'+str(key)+str(j)+'.xls'
            df_temporario = pd.read_excel(url)
        except:
            pass
            #url = 'http://www.prefeitura.sp.gov.br/cidade/secretarias/upload/Passag-2018'+str(month)+str(j)+'_Dados para Transparência.xls'
            #df_temporario = pd.read_excel(url)
        try:
            df_definitivo = pd.concat(df_definitvo, df_temporario)
        except:
            missing_values_list_2018.append('2018'+str(mes)+str(j))

# %%
df_temporario
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-095dd2a849c3> in <module>
# ----> 1 df_temporario
#
# NameError: name 'df_temporario' is not defined

# %%
len(missing_values_list_2018)
# Out:
# 360

# %%
missing_values_list_2019 = []
for key in month_list.keys():
    mes = month_list[key]
    for j in day_list:
        try :
            url = 'https://www.prefeitura.sp.gov.br/cidade/secretarias/upload/'+str(j)+str(month)+'2019'.xls'
            df_temporario = pd.read_excel(url)
            try:
                df_definitivo = pd.concat(df_definitvo, df_temporario)
            except:
                pass
        except:
            missing_values_list_2019.append(str(year)+str(month)+str(j))

# %%
df_definitivo.to_csv('passageiros.csv', header=True)

# %%
df_definitivo.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-87065497e92c> in <module>
# ----> 1 df_definitivo.head()
#
# NameError: name 'df_definitivo' is not defined

# %%
missing_values_list
# Out:
# ['2015dezembro1',
#  '2015dezembro2',
#  '2015dezembro3',
#  '2015dezembro4',
#  '2015dezembro5',
#  '2015dezembro6',
#  '2015dezembro7',
#  '2015dezembro8',
#  '2015dezembro9',
#  '2015dezembro10',
#  '2015dezembro11',
#  '2015dezembro12',
#  '2015dezembro13',
#  '2015dezembro14',
#  '2015dezembro15',
#  '2015dezembro16',
#  '2015dezembro17',
#  '2015dezembro18',
#  '2015dezembro19',
#  '2015dezembro20',
#  '2015dezembro21',
#  '2015dezembro22',
#  '2015dezembro23',
#  '2015dezembro24',
#  '2015dezembro25',
#  '2015dezembro26',
#  '2015dezembro27',
#  '2015dezembro28',
#  '2015dezembro29',
#  '2015dezembro30',
#  '2015dezembro1',
#  '2015dezembro2',
#  '2015dezembro3',
#  '2015dezembro4',
#  '2015dezembro5',
#  '2015dezembro6',
#  '2015dezembro7',
#  '2015dezembro8',
#  '2015dezembro9',
#  '2015dezembro10',
#  '2015dezembro11',
#  '2015dezembro12',
#  '2015dezembro13',
#  '2015dezembro14',
#  '2015dezembro15',
#  '2015dezembro16',
#  '2015dezembro17',
#  '2015dezembro18',
# ...
